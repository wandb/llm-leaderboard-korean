# %%
import glob
from pathlib import Path

# %%
fns = glob.glob('./artifacts/kaster:v0/kaster/dev/kmmlu*.json')

# %%
from pathlib import Path

fns = [Path(path).name for path in fns]
fns
# Out:
# ['kmmlu_Agricultural-Sciences.json',
#  'kmmlu_Aviation-Engineering-and-Maintenance.json',
#  'kmmlu_Aviation-Engineering-and-Maintenance_SymbolChoice.json',
#  'kmmlu_Accounting_SymbolChoice.json',
#  'kmmlu_Agricultural-Sciences_SymbolChoice.json',
#  'kmmlu_Biology_IncorrectChoice.json',
#  'kmmlu_Civil-Engineering_IncorrectChoice.json',
#  'kmmlu_Construction.json',
#  'kmmlu_Accounting.json',
#  'kmmlu_Biology.json',
#  'kmmlu_Chemistry.json',
#  'kmmlu_Civil-Engineering.json',
#  'kmmlu_Aviation-Engineering-and-Maintenance_IncorrectChoice.json',
#  'kmmlu_Agricultural-Sciences_IncorrectChoice.json',
#  'kmmlu_Accounting_IncorrectChoice.json',
#  'kmmlu_Chemical-Engineering.json',
#  'kmmlu_Chemistry_IncorrectChoice.json',
#  'kmmlu_Civil-Engineering_SymbolChoice.json',
#  'kmmlu_Computer-Science.json',
#  'kmmlu_Economics_IncorrectChoice.json',
#  'kmmlu_Criminal-Law_SymbolChoice.json',
#  'kmmlu_Construction_SymbolChoice.json',
#  'kmmlu_Ecology_SymbolChoice.json',
# ...

# %%
categories = set([fn.split('.')[0].split('kmmlu_')[1].split('_')[0] for fn in fns])

# %%
list(categories)
# Out:
# ['Aviation-Engineering-and-Maintenance',
#  'Education',
#  'Chemical-Engineering',
#  'math',
#  'Chemistry',
#  'Maritime-Engineering',
#  'korean-history',
#  'Mechanical-Engineering',
#  'Computer-Science',
#  'Marketing',
#  'Health',
#  'Psychology',
#  'Geomatics',
#  'Ecology',
#  'Electronics-Engineering',
#  'Information-Technology',
#  'Gas-Technology-and-Engineering',
#  'Construction',
#  'Railway-and-Automotive-Engineering',
#  'Patent',
#  'Energy-Management',
#  'Machine-Design-and-Manufacturing',
#  'Materials-Engineering',
#  'Accounting',
#  'Public-Safety',
#  'Law',
#  'Refrigerating-Machinery',
#  'Taxation',
#  'Telecommunications-and-Wireless-Technology',
#  'preview',
#  'Criminal-Law',
#  'Agricultural-Sciences',
#  'Biology',
#  'Management',
#  'Industrial-Engineer',
#  'Economics',
#  'Environmental-Science',
#  'Social-Welfare',
#  'Political-Science-and-Sociology',
#  'Nondestructive-Testing',
#  'Food-Processing',
# ...
